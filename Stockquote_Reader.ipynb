# %%
import bovespa

# %%
import pandas as pd

# %%
bf = bovespa.File('cotações/COTAHIST_A2019.TXT')

# %%
bf
# Out:
# File(path=cotações/COTAHIST_A2019.TXT)

# %%
for rec in bf.query():
    print('<{}, {}, {}, {}>'.format(rec.date, rec.stock_code, rec.price_close, rec.board_lot))
# Out:
# <2019-01-02, AALR3, 13.25, 1>
# <2019-01-02, AAPL34, 60.41, 1>
# <2019-01-02, ABBV34, 342.84, 1>
# <2019-01-02, ABCB4, 17.12, 1>
# <2019-01-02, ABEV3, 16.15, 1>
# <2019-01-02, ADHM3, 1.5, 1>
# <2019-01-02, AFLT3, 5.4, 1>
# <2019-01-02, AGRO3, 15.95, 1>
# <2019-01-02, ALPA3, 16.8, 1>
# <2019-01-02, ALPA4, 17.5, 1>
# <2019-01-02, ALSC3, 19.65, 1>
# <2019-01-02, ALUP3, 7.31, 1>
# <2019-01-02, ALUP4, 5.8, 1>
# <2019-01-02, ALUP11, 18.67, 1>
# <2019-01-02, AMAR3, 5.54, 1>
# <2019-01-02, AMGN34, 730.78, 1>
# <2019-01-02, AMZO34, 2953.46, 1>
# <2019-01-02, ANIM3, 18.01, 1>
# <2019-01-02, APER3, 18.0, 1>
# <2019-01-02, ARZZ3, 55.31, 1>
# <2019-01-02, ATOM3, 2.49, 1>
# <2019-01-02, ATTB34, 112.32, 1>
# <2019-01-02, AZEV4, 0.99, 1>
# <2019-01-02, AZUL4, 36.33, 1>
# <2019-01-02, B3SA3, 27.79, 1>
# <2019-01-02, BAHI3, 130.01, 1>
# <2019-01-02, BAUH4, 18.94, 1>
# <2019-01-02, BAZA3, 24.99, 1>
# <2019-01-02, BBAS3, 48.6, 1>
# <2019-01-02, BBDC3, 35.77, 1>
# <2019-01-02, BBDC4, 40.39, 1>
# ...
